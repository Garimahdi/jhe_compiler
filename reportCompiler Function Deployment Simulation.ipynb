# %%
import pandas as pd
import numpy as np
import sys
sys.path.append(r"C:\\Users\\Garimahdi.Supandi\\Hexindo Case")
import reportCompiler

# %%
lt1 = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\Lantai1HO.xlsx"
)
lt2 = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\Lantai 2 HO.xlsx"
)
lt3 = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\Lantai 3 HO.xlsx"
)
lt4 = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\Lantai 4 HO.xlsx"
)
jkt = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\Jakarta Branch.xlsx"
)
wh = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\Warehouse.xlsx"
)
yard = pd.read_excel(
    r"D:\Astragraphia\BO1\Hexindo\Job Log Analyzer\Raw Data AWMS\Data Wrangling via JHE\Jan Period\Rekap Des Jan\YARD.xlsx"
)

# %%
c1 = list(lt1.columns)
c2 = list(lt2.columns)
c3 = list(lt3.columns)
c4 = list(lt4.columns)
cj = list(jkt.columns)
cw = list(wh.columns)
cy = list(yard.columns)

# %%
print(c1[91])
print(cj[91])
print(cw[91])
print(cy[91])
print(c2[91])
print(c3[91])
print(c4[91])
# Out:
# Total Color Pages
# Total Color Pages
# Total Color Impressions
# Total Color Impressions
# Total Color Impressions
# Total Color Impressions
# Total Impresi Warna

# %%
db_user = pd.read_excel(r'D:\Astragraphia\BO1\Hexindo\Report Pemakaian\LDAP.xlsx')
cdu = list(db_user.columns)
print(db_user.info())
users = dict(db_user[[cdu[0],cdu[2]]].values)
depts = dict(db_user[[cdu[0],cdu[1]]].values)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   LDAP ID         1070 non-null   object
#  1   DEPT/BRANCH     1070 non-null   object
#  2   USER            1070 non-null   object
#  3   DEPT/BRANCH.1   1070 non-null   object
#  4   EMAIL ADDRESS   1063 non-null   object
# dtypes: object(5)
# memory usage: 41.9+ KB
# None

# %%
try:
    df_lt4 = reportCompiler.jheTranslator(lt4, lt3, c4, c3, 7)
    c4 = list(df_lt4.columns)
except Exception as e:
    print(e)

# %%
df_lt1 = reportCompiler.paperClr(lt1, c1)
df_lt2 = reportCompiler.paperClr(lt2, c2)
df_lt3 = reportCompiler.paperClr(lt3, c3)
df_lt4 = reportCompiler.paperClr(df_lt4, c4)
df_jkt = reportCompiler.paperClr(jkt, cj)
df_wh = reportCompiler.paperClr(wh, cw)
df_yard = reportCompiler.paperClr(yard, cy)

# %%
df_lt1['Paper Size'].unique()
# Out:
# array(['A4', 'Other', 'A3'], dtype=object)

# %%
df_lt1 = reportCompiler.userDeptMapping(df_lt1, users, depts, c1)
df_lt2 = reportCompiler.userDeptMapping(df_lt2, users, depts, c2)
df_lt3 = reportCompiler.userDeptMapping(df_lt3, users, depts, c3)
df_lt4 = reportCompiler.userDeptMapping(df_lt4, users, depts, c4)
df_jkt = reportCompiler.userDeptMapping(df_jkt, users, depts, cj)
df_wh = reportCompiler.userDeptMapping(df_wh, users, depts, cw)
df_yard = reportCompiler.userDeptMapping(df_yard, users, depts, cy)
# Out:
# C:\Users\Garimahdi.Supandi\Hexindo Case\reportCompiler.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nama'] = df[c[12]].map(dictUser)
# C:\Users\Garimahdi.Supandi\Hexindo Case\reportCompiler.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Dept'] = df[c[12]].map(dictDept)
# C:\Users\Garimahdi.Supandi\Hexindo Case\reportCompiler.py:130: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_lt1 = reportCompiler.filler(df_lt1, c1, 'Lantai 1 HO')
df_lt2 = reportCompiler.filler(df_lt2, c2, 'Lantai 2 HO')
df_lt3 = reportCompiler.filler(df_lt3, c3, 'Lantai 3 HO')
df_lt4 = reportCompiler.filler(df_lt4, c4, 'Lantai 4 HO')
df_jkt = reportCompiler.filler(df_jkt, cj, 'Jakarta Branch')
df_wh = reportCompiler.filler(df_wh, cw, 'Warehouse')
df_yard = reportCompiler.filler(df_yard, cy, 'Yard')
# Out:
# C:\Users\Garimahdi.Supandi\Hexindo Case\reportCompiler.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[c[12]] = df[c[12]].astype(str)
# C:\Users\Garimahdi.Supandi\Hexindo Case\reportCompiler.py:135: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Nama'] = df['Nama'].fillna(df[c[12]])
# C:\Users\Garimahdi.Supandi\Hexindo Case\reportCompiler.py:136: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_lt1 = reportCompiler.fillerTrans(df_lt1,df_lt3)
df_lt2 = reportCompiler.fillerTrans(df_lt2,df_lt3)
df_lt4 = reportCompiler.fillerTrans(df_lt4,df_lt3)
df_jkt = reportCompiler.fillerTrans(df_jkt,df_lt3)
df_wh = reportCompiler.fillerTrans(df_wh,df_lt3)
df_yard = reportCompiler.fillerTrans(df_yard,df_lt3)

# %%
def mergeData(d1,d2,d3=None,d4=None,d5=None,d6=None,d7=None,d8=None,d9=None,d10=None):
    if (d3 is None) and (d4 is None) and (d5 is None) and (d6 is None) and (d7 is None) and (d8 is None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1, d2])
        
    elif (d3 is not None) and (d4 is None) and (d5 is None) and (d6 is None) and (d7 is None) and (d8 is None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1,d2,d3])
        
    elif (d3 is not None) and (d4 is not None) and (d5 is None) and (d6 is None) and (d7 is None) and (d8 is None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1,d2,d3,d4])
    
    elif (d3 is not None) and (d4 is not None) and (d5 is not None) and (d6 is None) and (d7 is None) and (d8 is None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1,d2,d3,d4,d5])
        
    elif (d3 is not None) and (d4 is not None) and (d5 is not None) and (d6 is not None) and (d7 is None) and (d8 is None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1,d2,d3,d4,d5,d6])
        
    elif (d3 is not None) and (d4 is not None) and (d5 is not None) and (d6 is not None) and (d7 is not None) and (d8 is None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1,d2,d3,d4,d5,d6,d7])
        
    elif (d3 is not None) and (d4 is not None) and (d5 is not None) and (d6 is not None) and (d7 is not None) and (d8 is not None) and (d9 is None) and (d10 is None):
        merged = pd.concat([d1,d2,d3,d4,d5,d6,d7,d8])
        
    elif (d3 is not None) and (d4 is not None) and (d5 is not None) and (d6 is not None) and (d7 is not None) and (d8 is not None) and (d9 is not None) and (d10 is None):
        merged = pd.concat([d1,d2,d3,d4,d5,d6,d7,d8,d9])
        
    elif (d3 is not None) and (d4 is not None) and (d5 is not None) and (d6 is not None) and (d7 is not None) and (d8 is not None) and (d9 is not None) and (d10 is not None):
        merged = pd.concat([d1,d2,d3,d4,d5,d6,d7,d8,d9,d10])
    
    return merged

# %%
hexindo_proto = mergeData(
    df_lt1,
    df_lt2,
    df_lt3,
    df_lt4,
    df_jkt,
    df_wh,
    df_yard
)

# %%
hexindo_proto.head(30)
# Out:
# array([ 0,  8,  1,  6,  7, 69,  2,  4,  5,  3, 40, 18, 13, 10, 36, 14, 20,
#        60, 11, 31, 19, 15,  9, 21, 26, 25, 50, 29, 63, 24, 80, 22, 12, 41,
#        82], dtype=int64)
